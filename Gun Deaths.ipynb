# %%
import csv

# %%
df = open("C:\\Users\\Marcos\\DataQuest\\guns.csv","r")

# %%
csvreader = csv.reader(df)

# %%
GD = list(csvreader)

# %%
print(GD[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]

# %%
header = GD[:1]

# %%
data = GD[1:]

# %%
print(header)
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']]
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', '2']]

# %%
years = [row[1]for row in data]

# %%
years_counts = {}

# %%
for year in years:
    if year not in years_counts:
        years_counts[year] = 1
    else:
        years_counts[year] += 1

# %%
print(years_counts)
# Out:
# {'2012': 33563, '2013': 33636, '2014': 33599}

# %%
import datetime

# %%
dates = [datetime.datetime(year=int(row[1]),month = int(row[2]),day=1) for row in data]

# %%
dates[:5]
# Out:
# [datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 2, 1, 0, 0),
#  datetime.datetime(2012, 2, 1, 0, 0)]

# %%
date_counts = {}
for date in dates:
    if date not in date_counts:
        date_counts[date] = 0
        date_counts[date] += 1

# %%
date_counts
# Out:
# {datetime.datetime(2012, 1, 1, 0, 0): 1,
#  datetime.datetime(2012, 2, 1, 0, 0): 1,
#  datetime.datetime(2012, 3, 1, 0, 0): 1,
#  datetime.datetime(2012, 4, 1, 0, 0): 1,
#  datetime.datetime(2012, 5, 1, 0, 0): 1,
#  datetime.datetime(2012, 6, 1, 0, 0): 1,
#  datetime.datetime(2012, 7, 1, 0, 0): 1,
#  datetime.datetime(2012, 8, 1, 0, 0): 1,
#  datetime.datetime(2012, 9, 1, 0, 0): 1,
#  datetime.datetime(2012, 10, 1, 0, 0): 1,
#  datetime.datetime(2012, 11, 1, 0, 0): 1,
#  datetime.datetime(2012, 12, 1, 0, 0): 1,
#  datetime.datetime(2013, 1, 1, 0, 0): 1,
#  datetime.datetime(2013, 2, 1, 0, 0): 1,
#  datetime.datetime(2013, 3, 1, 0, 0): 1,
#  datetime.datetime(2013, 4, 1, 0, 0): 1,
#  datetime.datetime(2013, 5, 1, 0, 0): 1,
#  datetime.datetime(2013, 6, 1, 0, 0): 1,
#  datetime.datetime(2013, 7, 1, 0, 0): 1,
#  datetime.datetime(2013, 8, 1, 0, 0): 1,
#  datetime.datetime(2013, 9, 1, 0, 0): 1,
#  datetime.datetime(2013, 10, 1, 0, 0): 1,
#  datetime.datetime(2013, 11, 1, 0, 0): 1,
# ...

# %%
genero =  [row[5] for row in data]
sex_counts = {}
for sex in genero:
    if sex not in sex_counts:
        sex_counts[sex] = 0
    sex_counts[sex] += 1

# %%
sex_counts
# Out:
# {'M': 86349, 'F': 14449}

# %%
etnia = [row[7] for row in data]

# %%
race_counts = {}
for race in etnia:
    if race not in race_counts:
        race_counts[race] = 0
    race_counts[race] += 1

# %%
race_counts
# Out:
# {'Asian/Pacific Islander': 1326,
#  'White': 66237,
#  'Native American/Native Alaskan': 917,
#  'Black': 23296,
#  'Hispanic': 9022}

# %% [markdown]
# Baseado na exploração pela no dateset podemos idenficar que as mortes durantes os anos analisados que ha um numero acentuado de mortes de pessoas do genero masculino de etinia branca por armas de fogo

# %%
df = open("C:\\Users\\Marcos\\DataQuest\\census.csv","r")

# %%
readercsv = csv.reader(df)

# %%
census = list(readercsv)

# %%
census
# Out:
# [['Id',
#   'Year',
#   'Id',
#   'Sex',
#   'Id',
#   'Hispanic Origin',
#   'Id',
#   'Id2',
#   'Geography',
#   'Total',
#   'Race Alone - White',
#   'Race Alone - Hispanic',
#   'Race Alone - Black or African American',
#   'Race Alone - American Indian and Alaska Native',
#   'Race Alone - Asian',
#   'Race Alone - Native Hawaiian and Other Pacific Islander',
#   'Two or More Races'],
#  ['cen42010',
#   'April 1, 2010 Census',
#   'totsex',
#   'Both Sexes',
#   'tothisp',
#   'Total',
#   '0100000US',
#   '',
#   'United States',
#   '308745538',
#   '197318956',
#   '44618105',
#   '40250635',
#   '3739506',
#   '15159516',
#   '674625',
#   '6984195']]

# %%
mapping = {
          "Asian/Pacific Islander":15159516 + 674625,
          "Native American/Native Alaskan":3739506,
          "Black":40250635,
          "Hispanic":44618105,
          "White":197318956
}
race_hundred = {}
for k,v,in race_counts.items():
    race_hundred[k] = (v / mapping[k]) * 100000
    
race_hundred
# Out:
# {'Asian/Pacific Islander': 8.374309664161762,
#  'White': 33.56849303419181,
#  'Native American/Native Alaskan': 24.521955573811088,
#  'Black': 57.8773477735196,
#  'Hispanic': 20.220491210910907}

# %%
intents = [row[3]for row in data]
           
homiced_race_counts= {}
           
for i,race in enumerate(race):
    if race not in homiced_race_counts:
        homiced_race_counts[race] = 0
    if  intents[i] =="Homicede":
        homiced_race_counts[race] += 1

race_hundred = {}
for k,v, in homiced_race_counts.items():
    race_hundred[k] = (v / mapping[k]) * 100000
    
race_hundred
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-1714bd30278f> in <module>()
#      11 race_hundred = {}
#      12 for k,v, in homiced_race_counts.items():
# ---> 13     race_hundred[k] = (v / mapping[k]) * 100000
#      14
#      15 race_hundred
#
# KeyError: 'B'
